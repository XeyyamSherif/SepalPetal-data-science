# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df = pd.read_csv ('datasets/data_with_nans.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     171 non-null    int64
#  1   Id             171 non-null    int64
#  2   SepalLengthCm  168 non-null    float64
#  3   SepalWidthCm   170 non-null    float64
#  4   PetalLengthCm  167 non-null    float64
#  5   PetalWidthCm   169 non-null    float64
#  6   Species        171 non-null    object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 9.5+ KB

# %%
df.tail(20)
# Out:
#      Unnamed: 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 151         150  150            5.8           2.7            5.1
# 152         151  151            6.8           3.2            5.9
# 153         152  152            6.7           3.3            5.7
# 154         153  153            6.3           2.5            5.0
# 155         154  154            6.3           2.7            4.9
# 156         155  155            6.5           3.0            5.2
# 157         156  156            6.2           3.4            5.4
# 158         157  157            5.9           3.0            5.1
# 159         158  158            6.4           2.8            5.6
# 160         159  159            7.7           3.8            6.7
# 161         160  160            5.8           2.8            5.1
# 162         161  161            6.7           3.0            5.2
# 163         162  162            7.7           3.0            6.1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'],
#       dtype='object')

# %%
df.drop(labels=[df.columns[0]], axis=True, inplace=True)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   0            5.1           3.5            1.4           0.2  Iris-setosa
# 1   1            4.7           3.2            1.6           0.2  Iris-setosa
# 2   2            4.9           3.1            1.5           0.1  Iris-setosa
# 3   3            4.4           2.9            1.4           0.2  Iris-setosa
# 4   4            5.0           3.4            1.5           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  171.000000     168.000000    170.000000     167.000000    169.000000
# mean    84.549708       5.827381      3.074706       3.711976      1.182840
# std     49.078229       0.824817      0.446957       1.785038      0.763452
# min      0.000000       4.300000      2.000000       1.000000      0.100000
# 25%     42.500000       5.100000      2.800000       1.500000      0.300000
# 50%     85.000000       5.800000      3.000000       4.300000      1.300000
# 75%    126.500000       6.400000      3.400000       5.100000      1.800000
# max    169.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.groupby("Species").agg(["min", "max", "std", "mean"])
# Out:
#                   Id                             SepalLengthCm                 \
#                  min  max        std        mean           min  max       std
# Species
# Iris-setosa        0   59  17.464249   29.500000           4.3  6.9  0.429014
# Iris-versicolor   60  113  15.610408   86.618182           4.9  7.0  0.511380
# Iris-virginica   114  169  16.309506  141.500000           4.9  7.9  0.650025
#
#                           SepalWidthCm                          PetalLengthCm  \
#                      mean          min  max       std      mean           min
# Species
# Iris-setosa      5.034483          2.3  4.4  0.390709  3.389831           1.0
# Iris-versicolor  5.933333          2.0  4.4  0.387185  2.816364           1.5
# Iris-virginica   6.546429          2.2  3.9  0.355203  2.996429           1.3
#
#                                          PetalWidthCm
#                  max       std      mean          min  max       std      mean
# Species
# ...

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     1
# PetalLengthCm    4
# PetalWidthCm     2
# Species          0
# dtype: int64

# %%
for column in df.columns[1:-1]:
    df[column].fillna(value=df[column].mean(), inplace=True)

# %%
df["SepalLengthCm"].plot()
# Out:
# <AxesSubplot: >

# %%
for column in df.columns[1:-1]:
    sns.scatterplot(data=df, x="Id", y=column, hue="Species")
    plt.show()
